# %%
import pandas as pd
from dailycounts import TEST_DATE

# %%
df = pd.read_csv(r"E:\Projects\Learning\Data_Analytics_Projects\generate-analytics-report\data\time_series_covid19_confirmed_US.csv")

# %%
TEST_DATE
# Out:
# '10/20/20'

# %%
dates
# Out:
# ['UID',
#  'iso2',
#  'iso3',
#  'code3',
#  'FIPS',
#  'Admin2',
#  'Province_State',
#  'Country_Region',
#  'Lat',
#  'Long_',
#  'Combined_Key',
#  '1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
# ...

# %%
dates =list(df.columns)
df1=df.groupby('Province_State')[dates].agg('sum')

# %%
df1.cases=df1.diff(axis=1)[TEST_DATE]

# %%
index=df.columns.get_loc(TEST_DATE)
df.iloc[:, index]
# Out:
# 0       2010
# 1       6405
# 2        988
# 3        791
# 4       1848
#         ...
# 3335     716
# 3336     404
# 3337       0
# 3338     139
# 3339     101
# Name: 10/20/20, Length: 3340, dtype: int64

# %% [markdown]
# df1.dtypes

# %%
df1.cases
# Out:
# Province_State
# Alabama                     1043
# Alaska                       233
# American Samoa                 0
# Arizona                     1040
# Arkansas                     844
# California                  4101
# Colorado                    1208
# Connecticut                  434
# Delaware                     129
# Diamond Princess               0
# District of Columbia          50
# Florida                     3662
# Georgia                     1128
# Grand Princess                 0
# Guam                         130
# Hawaii                        88
# Idaho                        873
# Illinois                    3713
# Indiana                     1498
# Iowa                        1142
# Kansas                       622
# Kentucky                    1297
# Louisiana                    699
# Maine                         26
# Maryland                     590
# Massachusetts                976
# Michigan                    1871
# Minnesota                   1092
# ...
