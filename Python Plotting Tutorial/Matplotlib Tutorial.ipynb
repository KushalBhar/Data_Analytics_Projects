# %% [markdown]
# ## Read requried liberaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Real World Examples

# %% [markdown]
# ### Line Graph

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
plt.title("Gas Prices Over Time (in USD)")
plt.plot(gas.Year,gas.USA, 'b.-')
plt.plot(gas.Year,gas.Canada,'r.-')
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas['Australia'], 'y.-')

plt.xticks(gas.Year[::2])

plt.xlabel('Year Wise')
plt.ylabel('US Dollars')

# plt.ylabel('')

plt.legend(['USA','CANADA','South Korea','Australia'])

plt.show()

# %%
gas.shape
# Out:
# (19, 11)

# %%
print(country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(country)
#
# NameError: name 'country' is not defined

# %%
plt.title("Gas Prices Over Time (in USD)", fontdict={'fontweight':'bold','fontsize':12,'color':'b'})
country_list =[]
# for country in gas.iloc[:,1:]:
#     plt.plot(gas.Year, gas[country], marker = '.')
#     country_list.append(country)
    
countries_to_look_at = ['Australia','USA','Canada','South Korea']

for country in countries_to_look_at:
    plt.plot(gas.Year, gas[country], marker = '.')
    country_list.append(country)

plt.xticks(gas.Year[::2])

plt.xlabel('Year Wise')
plt.ylabel('US Dollars')

# plt.ylabel('')

plt.legend(country_list,bbox_to_anchor=(1.0, 1.02))

plt.savefig('Gas_price_figure',bbox_inches='tight',dpi = 300)

plt.show()

# %% [markdown]
# ## Load Fifa data

# %%
fifa = pd.read_csv('fifa_data.csv')

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# Display options
pd.options.display.max_columns = 100

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa[fifa['Name']=='Cristiano Ronaldo']
# Out:
#    Unnamed: 0     ID               Name  Age  \
# 1           1  20801  Cristiano Ronaldo   33
#
#                                            Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential      Club  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94  Juventus
#
#                                      Club Logo Value   Wage  Special  \
# 1  https://cdn.sofifa.org/teams/2/light/45.png  €77M  €405K     2228
#
#   Preferred Foot  International Reputation  Weak Foot  Skill Moves  Work Rate  \
# 1          Right                       5.0        4.0          5.0  High/ Low
#
#     Body Type Real Face Position  Jersey Number        Joined Loaned From  \
# 1  C. Ronaldo       Yes       ST            7.0  Jul 10, 2018         NaN
#
#   Contract Valid Until Height  Weight    LS    ST    RS    LW    LF    CF  \
# ...

# %% [markdown]
# ## Histograms

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(fifa.Overall,bins =bins, color='#34ebae')

plt.xticks(bins)
plt.ylabel("Number of Players")
plt.xlabel("Skill Level")
plt.title("Distribution of Player Skills in FIFA 2018")
# plt.legend()
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Pie Charts

# %%
# Out:
# 13948

# %%
left = fifa.loc[fifa['Preferred Foot'] =='Left'].count()[0]

right =fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
labels = ['Left','Right']

colors = ['#34e2eb','#6b34eb']

plt.pie([left,right] , labels=labels,colors=colors,autopct='%.2f %%')

plt.title('Food Preference of Fifa Players')

plt.show()

# %%
fifa.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
fifa.Weight =[int(x.strip('lbs')) if type(x) ==str else x for x in fifa.Weight ]

# %%
barcelona=fifa.loc[fifa.Club =='FC Barcelona']['Overall']

Madrid=fifa.loc[fifa.Club =='Real Madrid']['Overall']

revs = fifa.loc[fifa.Club =='New England Revolution']['Overall']

labels = ['barcelona','Madrid','New England Revolution']

plt.boxplot([barcelona,Madrid,revs],labels=labels)

plt.title('Professtional Soccer Team Comparison')

plt.show()

# %%
#
