# %% [markdown]
# # 1. Run Terminal Commands in Jupyter

# %%
# !pip install seaborn

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !dir
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is B0BB-F13E
#
#  Directory of E:\Projects\Learning\Data_Analytics_Projects\Jupyter Notebook Tips & Tricks
#
# 24-12-2023  15:12    <DIR>          .
# 23-12-2023  17:20    <DIR>          ..
# 24-12-2023  15:09    <DIR>          .ipynb_checkpoints
# 24-12-2023  15:12    <DIR>          saini
# 24-12-2023  15:10             3,896 Tips-and_tricks_jupyter_notebook.ipynb
#                1 File(s)          3,896 bytes
#                4 Dir(s)  224,813,580,288 bytes free

# %%
# !cd saini & dir
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is B0BB-F13E
#
#  Directory of E:\Projects\Learning\Data_Analytics_Projects\Jupyter Notebook Tips & Tricks\saini
#
# 24-12-2023  15:12    <DIR>          .
# 24-12-2023  15:14    <DIR>          ..
# 24-12-2023  15:12                 0 New Text Document.txt
#                1 File(s)              0 bytes
#                2 Dir(s)  224,813,576,192 bytes free

# %%
# !cd
# Out:
# E:\Projects\Learning\Data_Analytics_Projects\Jupyter Notebook Tips & Tricks

# %%
# !wsl cowsay "kushal is really cool"
# Out:
# Copyright (c) Microsoft Corporation. All rights reserved.
#
#
#
#
#
# Usage: wsl.exe [Argument]
#
#
#
#
#
# Arguments:
#
#
#
#
#
#     --install <Options>
#
#
#         Install Windows Subsystem for Linux features. If no options are specified,
#
#
#         the recommended features will be installed along with the default distribution.
#
#
#
#
#
#         To view the default distribution as well as a list of other valid distributions,
#
#
#         use 'wsl --list --online'.
#
#
#
#
#
#         Options:
#
#
#             --distribution, -d [Argument]
#
#
#                 Specifies the distribution to be downloaded and installed by name.
#
#
#
#
#
#                 Arguments:
#
#
#                     A valid distribution name (not case sensitive).
#
#
#
#
#
#                 Examples:
#
#
#                     wsl --install -d Ubuntu
#
#
#                     wsl --install --distribution Debian
#
#
#
#
#
#             --inbox
#
#
# ...

# %% [markdown]
# # 2. Shortcuts in Jupyter Notebooks

# %% [markdown]
# M: Switch to markdown <br/>
# A: create cell above <br/>
# B: create cell below <br/>
# d+d delete the cell <br/>
#
#
# ctrl + enter : run cell and stay on cell <br/>
# shift + enter : run cell and go the next
#
#
# edit --> find and replace

# %% [markdown]
# # 3. Changing Pandas Display Options

# %%
import pandas as pd

df = pd.read_csv(r"Diwali Sales Data.csv",encoding='latin-1')

# %%
df.head(100)
# Out:
#     User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903   Sanskriti  P00125942      F     26-35   28               0
# 1   1000732      Kartik  P00110942      F     26-35   35               1
# 2   1001990       Bindu  P00118542      F     26-35   35               1
# 3   1001425      Sudevi  P00237842      M      0-17   16               0
# 4   1000588        Joni  P00057942      M     26-35   28               1
# ..      ...         ...        ...    ...       ...  ...             ...
# 95  1004416       Airdo  P00213742      F     18-25   23               0
# 96  1000850      Bhawna  P00319942      F     36-45   44               0
# 97  1002888  Corey-Lock  P00255842      F     26-35   34               0
# 98  1001891        Akin  P00192542      F     46-50   46               0
# 99  1001019        Neil  P00259142      F     36-45   43               1
#
#              State      Zone       Occupation  Product_Category  Orders  \
# ...

# %%
pd.options.display.max_rows = 100

# %%
pd.options.display.max_columns = 50

# %%
df.head(100)
# Out:
#     User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903    Sanskriti  P00125942      F     26-35   28               0
# 1   1000732       Kartik  P00110942      F     26-35   35               1
# 2   1001990        Bindu  P00118542      F     26-35   35               1
# 3   1001425       Sudevi  P00237842      M      0-17   16               0
# 4   1000588         Joni  P00057942      M     26-35   28               1
# 5   1000588         Joni  P00057942      M     26-35   28               1
# 6   1001132         Balk  P00018042      F     18-25   25               1
# 7   1002092     Shivangi  P00273442      F       55+   61               0
# 8   1003224       Kushal  P00205642      M     26-35   35               0
# 9   1003650        Ginny  P00031142      F     26-35   26               1
# 10  1003829     Harshita  P00200842      M     26-35   34               0
# 11  1000214     Kargatis  P00119142      F     18-25   20               0
# ...

# %%
pd.options.display.max_colwidth = 50

# %%
df.head(50)
# Out:
#     User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903    Sanskriti  P00125942      F     26-35   28               0
# 1   1000732       Kartik  P00110942      F     26-35   35               1
# 2   1001990        Bindu  P00118542      F     26-35   35               1
# 3   1001425       Sudevi  P00237842      M      0-17   16               0
# 4   1000588         Joni  P00057942      M     26-35   28               1
# 5   1000588         Joni  P00057942      M     26-35   28               1
# 6   1001132         Balk  P00018042      F     18-25   25               1
# 7   1002092     Shivangi  P00273442      F       55+   61               0
# 8   1003224       Kushal  P00205642      M     26-35   35               0
# 9   1003650        Ginny  P00031142      F     26-35   26               1
# 10  1003829     Harshita  P00200842      M     26-35   34               0
# 11  1000214     Kargatis  P00119142      F     18-25   20               0
# ...

# %% [markdown]
# ## Setting up alerts when cells finished

# %%
# !pip install jupyternotify

# %%
# %load_ext jupyternotify
# Out:
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify

# %%
# %%notify
#
# import time
# import random
#
#
# r = random.randint(30,60)
# time.sleep(15)
#
#
# print("Cell Finished execution")
# Out:
# Cell Finished execution

# %% [markdown]
# ## 5. Create a slideshow out of your notebook

# %% [markdown]
# view --> Cell Toolbar >> slideshow

# %% [markdown]
# Slides - main option <br/>
# Sub-slide - fill full screen <br/>
# Fragments -underneath slide/sub-slide add additional information <br/>
# Skip - don't include cell<br/>
# Notes - Don't inculde cell <br/>
